# %%
from diceclass import DICE2016Model
import matplotlib.pyplot as plt

# %%
model = DICE2016Model()
model.run_model()
# Out:
# Optimal solution value: 5301.092483698273

# %%
output=model.results
output
# Out:
#              MAT      CCATOT         PPM    ATFRAC  ATFRAC2010          E  \
# time
# 0     851.000000  500.000000  400.659134  0.526000    0.000000  38.340385
# 1     891.331850  552.291850  419.647764  0.549224    0.771284  35.445921
# 2     925.088868  600.635987  435.540899  0.561220    0.736206  37.200465
# 3     959.900361  651.373119  451.930490  0.570948    0.719417  38.633499
# 4     995.444868  704.064742  468.665192  0.578704    0.707838  39.703922
# ...          ...         ...         ...       ...         ...        ...
# 95    526.664230  130.841279  247.958677 -0.468780    0.878581   0.001085
# 96    526.927319  130.842759  248.082542 -0.466764    0.877872   0.001863
# 97    527.190302  130.845300  248.206357 -0.464745    0.877165   0.014943
# 98    527.469866  130.865680  248.337978 -0.462536    0.876456   3.395042
# 99    532.356162  135.496125  250.638495 -0.410667    0.874185   9.948612
#
# ...

# %%
plt.plot(output.index,output['TATM'])
